# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # DNS Seeds

# %% [markdown]
# By this time you've probably hit this error:
#
# ![image](../images/empty-list.png)
#
# It would be much better if we could prime our crawler with more addresses. It would be especially good if they were addresses of "high quality" nodes that are always online and have juicy peer lists to share with us.
#
# This is exactly what DNS seeds are for. Prominent bitcoin core developers run DNS servers from domains they contol which resolve not to the address of a machine serving a website -- which is true of most domain names -- but to a list of addresses of high quality bitcoin full nodes.
#
# These domains are actually [hard-coded into Bitcoin Core](https://github.com/bitcoin/bitcoin/blob/v0.17.1/src/chainparams.cpp#L127)!
#
# Some of them run [this crawler / server written by Peter Wuille](https://github.com/sipa/bitcoin-seeder).
#
# Let's learn to query these DNS seeds:

# %% [markdown]
# In your terminal type:
#
# ```shell
# $ dig dnsseed.bitcoin.dashjr.org
# ```
#
# This will perform a DNS lookup. We are interest in the "answers" sections, which shows a number of DNS "A records" for the host name `dnsseed.bitcoin.dashjr.org`. These are IP addresses of Bitcoin nodes!
#
# ![image](../images/dig.png)
#
#
# How can we do this from Python?
#
# Python's built-in [`socket.getaddrinfo`](https://docs.python.org/3/library/socket.html#socket.getaddrinfo) function can accomplish this.

# %%
# Copied from Bitcoin Core's src/chainparams.cpp file

DNS_SEEDS = [
    'dnsseed.bitcoin.dashjr.org', 
    'dnsseed.bluematt.me',
    'seed.bitcoin.sipa.be', 
    'seed.bitcoinstats.com',
    'seed.bitcoin.jonasschnelli.ch',
    'seed.btc.petertodd.org',
    'seed.bitcoin.sprovoost.nl',
    'dnsseed.emzy.de',
]

# %%
import socket

# getaddrinfo translates hostname -> ip address ... but it's messy
addr_info = socket.getaddrinfo(DNS_SEEDS[0], 8333)
addr_info
# Out:
# [(<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2400:8901::f03c:91ff:fe81:6c06', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2400:8901::f03c:91ff:fe81:6c06', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2400:8901::f03c:91ff:fe81:6c06', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:8d8:939:1900::77:9e09', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2001:8d8:939:1900::77:9e09', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2001:8d8:939:1900::77:9e09', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:41d0:2:84a7::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2001:41d0:2:84a7::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2001:41d0:2:84a7::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:41d0:8:6d30::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2001:41d0:8:6d30::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2001:41d0:8:6d30::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:41d0:52:d00::6e3', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2001:41d0:52:d00::6e3', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2001:41d0:52:d00::6e3', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:41d0:800:664::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2001:41d0:800:664::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2001:41d0:800:664::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:41d0:1004:19b4::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2001:41d0:1004:19b4::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2001:41d0:1004:19b4::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:4800:7811:513:be76:4eff:fe04:39ae', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2001:4800:7811:513:be76:4eff:fe04:39ae', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2001:4800:7811:513:be76:4eff:fe04:39ae', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:48f8:72:1a:803d:4398:b750:3bd5', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2001:48f8:72:1a:803d:4398:b750:3bd5', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2001:48f8:72:1a:803d:4398:b750:3bd5', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2a01:4f8:202:34ca::2', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2a01:4f8:202:34ca::2', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2a01:4f8:202:34ca::2', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2a02:7b40:592f:a590::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2a02:7b40:592f:a590::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2a02:7b40:592f:a590::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2a02:7b40:b0df:8258::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('2a02:7b40:b0df:8258::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_RAW: 3>,
#   0,
#   '',
#   ('2a02:7b40:b0df:8258::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2a05:6d40:b94e:d100:225:90ff:fe0d:cfc2', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('
 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('93.232.190.173', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('167.99.212.230', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('173.212.219.76', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('176.9.105.208', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('176.9.150.167', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.62.34.210', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('185.102.71.6', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('209.222.98.74', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('13.78.35.135', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.185.88.16', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('24.121.17.110', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('31.207.168.116', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('34.245.48.56', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('40.115.137.28', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('45.79.103.28', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('47.223.66.222', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('51.15.167.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('51.68.210.144', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('52.78.60.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.246.181.228', 8333)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2002:d4cc:bec8::d4cc:bec8', 8333, 0, 0))]

# %%
# Question: how would you getch the addresses configured for UDP?

socket.getaddrinfo(DNS_SEEDS[0], 8333, socket.AF_INET, socket.SOCK_DGRAM)
# Out:
# [(<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('51.15.167.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('51.68.210.144', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('52.78.60.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('54.246.181.228', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('83.53.168.121', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('90.190.111.66', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('90.191.240.128', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('92.222.180.15', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('93.232.190.173', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('167.99.212.230', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('173.212.219.76', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('176.9.105.208', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('176.9.150.167', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('178.62.34.210', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('185.102.71.6', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('209.222.98.74', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('13.78.35.135', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('18.185.88.16', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('24.121.17.110', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('31.207.168.116', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('34.245.48.56', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('40.115.137.28', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('45.79.103.28', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('47.223.66.222', 8333))]

# %%
# We want to accept IPv4 & IPv6 (3rd param set to 0)
# But only TCP socket types (4th param set to socket.SOCK_STREAM)
addr_info = socket.getaddrinfo(DNS_SEEDS[0], 8333, 0, socket.SOCK_STREAM)
addr_info
# Out:
# [(<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2400:8901::f03c:91ff:fe81:6c06', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:8d8:939:1900::77:9e09', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:41d0:2:84a7::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:41d0:8:6d30::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:41d0:52:d00::6e3', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:41d0:800:664::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:41d0:1004:19b4::', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:4800:7811:513:be76:4eff:fe04:39ae', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2001:48f8:72:1a:803d:4398:b750:3bd5', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2a01:4f8:202:34ca::2', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2a02:7b40:592f:a590::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2a02:7b40:b0df:8258::1', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2a05:6d40:b94e:d100:225:90ff:fe0d:cfc2', 8333, 0, 0)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('91.11.83.247', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('93.232.190.173', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('94.130.239.161', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('95.216.35.94', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('104.172.92.92', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('141.72.245.201', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('162.255.117.213', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('173.249.5.240', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.128.247.160', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('217.119.121.123', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('5.189.166.193', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('34.205.147.134', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('37.59.50.14', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('45.77.205.198', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('47.90.244.228', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('47.199.73.254', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('51.15.176.153', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('64.90.166.178', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('65.27.104.112', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('67.169.6.126', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('67.207.75.7', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('70.114.197.226', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('72.229.134.90', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('81.4.102.69', 8333)),
#  (<AddressFamily.AF_INET6: 10>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('2002:d4cc:bec8::d4cc:bec8', 8333, 0, 0))]

# %%
# addresses in the last entry
addrs = [ai[-1] for ai in addr_info]
addrs
# Out:
# [('2400:8901::f03c:91ff:fe81:6c06', 8333, 0, 0),
#  ('2001:8d8:939:1900::77:9e09', 8333, 0, 0),
#  ('2001:41d0:2:84a7::', 8333, 0, 0),
#  ('2001:41d0:8:6d30::1', 8333, 0, 0),
#  ('81.4.102.69', 8333),
#  ('2002:d4cc:bec8::d4cc:bec8', 8333)]

# %%
from mycrawler import Node

# Turn them into Node instances
nodes = [Node(*addr) for addr in addrs]

nodes
# Out:
# [<mycrawler.Node at 0x7f7aa748ebe0>,
#  <mycrawler.Node at 0x7f7aa748e208>,
#  <mycrawler.Node at 0x7f7aa748e7b8>,
#  <mycrawler.Node at 0x7f7aa748ec88>,
#  <mycrawler.Node at 0x7f7aa748e5f8>,
#  <mycrawler.Node at 0x7f7aa748e828>,
#  <mycrawler.Node at 0x7f7aa748eba8>,
#  <mycrawler.Node at 0x7f7aa748ee80>,
#  <mycrawler.Node at 0x7f7aa748ec18>,
#  <mycrawler.Node at 0x7f7aa748e438>,
#  <mycrawler.Node at 0x7f7aa748e9b0>,
#  <mycrawler.Node at 0x7f7aa748e780>,
#  <mycrawler.Node at 0x7f7aa748eb38>,
#  <mycrawler.Node at 0x7f7aa748ea90>,
#  <mycrawler.Node at 0x7f7aa748ecf8>,
#  <mycrawler.Node at 0x7f7aa748e400>,
#  <mycrawler.Node at 0x7f7aa748edd8>,
#  <mycrawler.Node at 0x7f7aa748eeb8>,
#  <mycrawler.Node at 0x7f7aa748e860>,
#  <mycrawler.Node at 0x7f7aa748ea58>,
#  <mycrawler.Node at 0x7f7aa748ee48>,
#  <mycrawler.Node at 0x7f7aa748ed68>,
#  <mycrawler.Node at 0x7f7aa748e5c0>,
#  <mycrawler.Node at 0x7f7aa748ec50>,
#  <mycrawler.Node at 0x7f7aa748e390>,
#  <mycrawler.Node at 0x7f7aa748e0b8>,
#  <mycrawler.Node at 0x7f7aa748e278>,
#  <mycrawler.Node at 0x7f7aa748e8d0>,
#  <mycrawler.Node at 0x7f7aa748e6d8>,
#  <mycrawler.Node at 0x7f7aa748e7f0>,
#  <mycrawler.Node at 0x7f7aa748ee10>,
#  <mycrawler.Node at 0x7f7aa748e748>,
#  <mycrawler.Node at 0x7f7aa748e550>,
#  <mycrawler.Node at 0x7f7aa748ecc0>,
#  <mycrawler.Node at 0x7f7aa748e6a0>,
#  <mycrawler.Node at 0x7f7aa748e898>,
#  <mycrawler.Node at 0x7f7aa748e160>,
#  <mycrawler.Node at 0x7f7aa748e4e0>]

# %%
from mycrawler import Connection

# Can we connect?
conn = Connection(nodes[0]).open()
# Out:
# Connecting to 2400:8901::f03c:91ff:fe81:6c06
# Received a "version"
# Received a "verack"
# Received a "sendheaders"
# Received a "sendcmpct"
# Received a "sendcmpct"
# Received a "ping"
# Received a "addr"
# Received a "getheaders"
# Received a "feefilter"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-4f5c1380be17> in <module>
#       2
#       3 # Can we connect?
# ----> 4 conn = Connection(nodes[0]).open()
#
# ~/dev/network-programming/4. Crawling The Bitcoin Network/mycrawler.py in open(self)
#     103         # Handle messages until program exists
#     104         while self.remain_alive():
# --> 105             self.handle_msg()
#     106
#     107     def close(self):
#
# ~/dev/network-programming/4. Crawling The Bitcoin Network/mycrawler.py in handle_msg(self)
#      77
#      78     def handle_msg(self):
# ---> 79         msg = read_msg(self.stream)
#      80         command = msg['command'].decode()
#      81         print(f'Received a "{command}"')
#
# ~/dev/network-programming/4. Crawling The Bitcoin Network/lib.py in read_msg(stream)
#     166
#     167 def read_msg(stream):
# --> 168     magic = stream.read(4)
#     169     if magic != NETWORK_MAGIC:
#     170         raise BitcoinProtocolError(f'Magic is wrong: {magic}')
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def query_dns_seeds():
    nodes = []
    for seed in DNS_SEEDS:
        try:
            addr_info = socket.getaddrinfo(seed, 8333, 0, socket.SOCK_STREAM)
            addresses = [ai[-1][:2] for ai in addr_info]
            nodes.extend([Node(*addr) for addr in addresses])
        except OSError as e:
            print(f"DNS seed query failed: {str(e)}")
    return nodes

# %%
# BEHOLD THE GLORIOUS BITCOIN NODES!!!

for node in query_dns_seeds():
    print(node.ip)
# Out:
# 2400:8901::f03c:91ff:fe81:6c06
# 2001:41d0:1004:19b4::
# 2001:4800:7811:513:be76:4eff:fe04:39ae
# 2001:48f8:72:1a:803d:4398:b750:3bd5
# 2001:8d8:939:1900::77:9e09
# 2001:41d0:2:84a7::
# 2001:41d0:8:6d30::1
# 2001:41d0:52:d00::6e3
# 2001:41d0:800:664::
# 2a01:4f8:202:34ca::2
# 2a02:7b40:592f:a590::1
# 2a02:7b40:b0df:8258::1
# 2a05:6d40:b94e:d100:225:90ff:fe0d:cfc2
# 178.62.34.210
# 185.102.71.6
# 209.222.98.74
# 13.78.35.135
# 18.185.88.16
# 24.121.17.110
# 31.207.168.116
# 34.245.48.56
# 40.115.137.28
# 45.79.103.28
# 47.223.66.222
# 51.15.167.35
# 51.68.210.144
# 52.78.60.35
# 54.246.181.228
# 83.53.168.121
# 90.190.111.66
# 90.191.240.128
# 92.222.180.15
# 93.232.190.173
# 167.99.212.230
# 173.212.219.76
# 176.9.105.208
# 176.9.150.167
# 2002:d4cc:bec8::d4cc:bec8
# 2600:6c64:647f:fa84:c001:aa46:2689:d29d
# 2600:6c64:647f:fa84:c056:213a:ee61:4ec2
# 2001:638:a000:4140::ffff:191
# 2001:1970:5c27:8c00:34ec:9794:74a2:9a6
# 2a02:7b40:c287:5257::1
# 2a02:810d:440:3030:904d:6fba:e9d2:8f96
# 2a05:6d40:b94e:d100:225:90ff:fe0d:cfc2
# 2804:14c:65c0:4e0::1
# 2a00:1630:2:500::4
# 2a01:4f8:140:322b::2
# 2a01:4f8:c0c:37c::2
# 2a01:4f9:2a:201b::2
# 87.230.22.85
# 144.76.56.120
# 157.13.61.136
# 162.144.37.34
# 172.105.194.235
# 173.212.236.28
# 184.179.105.34
# 185.85.3.140
# 194.59.207.89
# 199.116.240.44
# 5.9.150.168
# 23.106.139.63
# 45.76.217.84
# 45.117.40.81
# 46.166.142.2
# 62.210.208.131
# 71.84.104.71
# 71.88.108.14
# 71.222.111.159
# 85.214.68.122
# 87.65.146.108
# 87.188.157.64
# 88.13.58.225
# 92.249.221.231
# 97.125.12.224
# 104.156.49.236
# 139.59.34.217
# 139.59.146.142
# 142.93.30.86
# 178.33.24.77
# 178.83.115.159
# 178.218.209.162
# 191.255.115.90
# 2.31.186.123
# 13.229.89.81
# 13.229.122.58
# 46.4.105.19
# 46.101.153.114
# 47.94.158.75
# 54.249.149.204
# 62.75.210.81
# 67.240.32.102
# 70.184.93.163
# 80.98.24.110
# 85.214.204.63
# 86.61.67.183
# 2607:5300:203:1112::
# 2600:1f16:625:e00:cd15:b9f2:6e3e:6fd1
# 2406:da18:f7c:4351:c993:eb06:bd2c:1e65
# 2409:8a14:ae45:5b80:2e0:70ff:fe88:4d6
# 2001:470:1f08:3cc::2
# 2001:41d0:2:e45a::
# 2a02:c205:3002:6525::1
# 2a03:b0c0:3:d0::23fb:1
# 2a03:b0c0:3:d0::23fb:3001
# 2a03:b0c0:3:d0::2400:f001
# 2a03:b0c0:3:d0::2403:7001
# 2a03:b0c0:3:d0::2404:6001
# 2a03:b0c0:3:d0::2405:2001
# 2a03:b0c0:3:d0::2405:7001
# 2a05:1700::100
# 2a05:d014:d7e:a001:39f2:885b:7f64:92b2
# 2a00:bbe0:cc:0:6651:6ff:fe0e:9418
# 2a01:4f8:141:4d7::2
# 2a01:4f8:150:2088::2
# 2a01:4f8:173:1622::2
# 2a01:7c8:aac2:180:5054:ff:fe56:8d10
# 2a01:e35:8b0c:5990:e054:ca7c:1356:3629
# 2a02:908:211:1a60:39bf:d4aa:60b2:d9c3
# 2a02:908:4f0:7e1c:5054:ff:feb7:ce4b
# 2a02:7b40:c3b5:f287::1
# 2.229.239.77
# 3.0.126.199
# 5.189.162.177
# 46.101.187.98
# 47.254.30.200
# 50.46.122.78
# 51.15.3.46
# 51.68.36.56
# 54.197.4.92
# 72.161.140.241
# 74.78.139.4
# 77.0.79.152
# 82.64.89.251
# 85.86.30.194
# 87.162.155.221
# 94.26.49.71
# 95.216.28.120
# 138.68.92.65
# 145.239.4.46
# 157.13.61.130
# 162.255.116.24
# 212.51.140.183
# 212.232.28.171
# 213.211.147.247
# 217.182.138.68
# 2603:300b:901:bb00::36b2
# 2a01:7a7:2:131b:20c:29ff:fe9a:3922
# 98.5.4.22
# 106.3.46.98
# 108.255.198.109
# 109.153.200.183
# 115.68.109.9
# 117.62.47.174
# 122.53.255.92
# 172.81.181.146
# 180.107.145.242
# 208.67.251.126
# 213.89.97.109
# 1.255.101.158
# 3.0.172.253
# 5.189.183.65
# 13.59.127.10
# 23.225.199.211
# 35.161.108.245
# 52.14.41.63
# 72.213.57.227
# 78.46.99.198
# 79.98.106.155
# 88.249.228.174
# 92.107.252.122
# 93.33.192.204
# 2001:0:4137:9e76:10c2:2f80:9d3d:7f02
# 2001:0:4137:9e76:30c6:355c:b954:92d9
# 2001:0:5ef5:79fb:20b0:3d81:276e:6d54
# 2001:0:5ef5:79fb:2cbb:a940:e72a:140d
# 2001:0:9d38:6ab8:851:21ff:923c:c28
# 2001:0:9d38:6ab8:147f:7d7e:2bd2:fc45
# 2001:0:9d38:6ab8:14da:1e3:2669:d946
# 2001:0:9d38:6ab8:1c5e:626:7756:7a69
# 2001:0:9d38:6ab8:2046:2bb4:4dc6:e231
# 2001:0:9d38:6ab8:24a7:bc0:d140:1031
# 2001:0:9d38:6ab8:282b:130:a05a:69a4
# 2001:0:9d38:6ab8:2865:f50:a2ae:1426
# 178.128.19.243
# 183.193.212.218
# 185.141.64.106
# 210.180.118.141
# 3.16.3.121
# 23.175.0.222
# 35.158.135.198
# 35.187.219.4
# 45.76.165.162
# 47.185.249.138
# 52.78.200.40
# 58.161.228.85
# 63.33.118.59
# 78.21.94.247
# 82.34.181.192
# 88.99.188.128
# 95.211.189.3
# 95.216.97.16
# 116.203.60.14
# 117.81.184.198
# 133.205.229.145
# 136.27.10.6
# 147.135.132.185
# 2600:1f14:34a:fe00:d5ee:a3e2:2f85:e593
# 2001:bc8:4400:2100::1:b03
# 2001:470:8:bd3:4d25:ca57:a5b7:c6c4
# 2001:470:1c:9f7::2
# 2001:470:28:365::7
# 2001:470:1f05:43b:7182:8182:8459:452
# 2001:470:1f08:3cc::2
# 2001:470:1f1b:5a6:216:3eff:fe24:1162
# 2001:470:1f29:1a:645e:bf26:d0c7:859f
# 2001:470:b3d5:1::19
# 2001:470:ddc1:20:feaa:14ff:fe2f:694b
# 2a01:4f8:10b:41::2
# 2a01:4f8:201:1132::2
# 201.233.98.209
# 213.174.156.70
# 5.9.235.53
# 13.251.210.202
# 24.16.142.127
# 24.119.244.250
# 31.201.244.92
# 35.185.137.70
# 45.76.217.84
# 54.250.48.229
# 58.179.220.201
# 67.205.137.64
# 84.217.175.166
# 99.130.62.243
# 103.18.124.164
# 104.205.201.99
# 108.161.119.169
# 117.102.191.217
# 149.167.228.228
# 176.51.81.236
# 188.17.152.8
# 194.58.88.93
# 240e:82:702:428:d588:8f2a:be52:d63a
# 2001:67c:16dc:1201:5054:ff:fe17:4dac
# 2001:985:c344:1:ba27:ebff:fe5d:21de
# 2001:ba8:1f1:f34c::2
# 2001:bc8:6006:10:1a66:daff:fe93:8320
# 2001:da8:215:848:d294:66ff:fe3e:62e1
# 2001:4128:6135:2010:21e:bff:fee8:a3c0
# 2001:41d0:1:8e75::1
# 2001:41d0:8:b7d0::1
# 2a03:b0c0:3:d0::2402:b001
# 2a01:4f8:13b:4197::2
# 2a02:7aa0:1619::a7a2:7e86
# 67.187.170.63
# 67.207.75.7
# 71.218.51.209
# 72.226.19.195
# 78.46.190.34
# 78.140.27.66
# 80.229.147.76
# 85.214.210.168
# 85.216.147.163
# 86.40.226.171
# 88.11.166.255
# 104.236.64.173
# 157.52.11.44
# 173.249.49.254
# 195.154.168.55
# 199.189.87.46
# 208.38.44.251
# 218.75.158.233
# 5.9.94.237
# 13.239.74.62
# 37.20.158.103
# 43.242.35.77
# 46.4.102.45
# 46.101.109.46
# 46.227.71.108
# 62.210.82.50
# 2001:0:9d38:6ab8:14f8:365:2bf9:fd81
# 2001:0:9d38:6ab8:28b5:1c97:430d:3eb6
# 2001:0:9d38:6abd:3410:3fc0:4610:1132

# %% [markdown]
# BTW -- we're already using `getaddrinfo` under the hood when we call `socket.create_connection` ...
